# %%
import pandas as pd

drug_df = pd.read_csv("Data/drug200.csv")
drug_df = drug_df.sample(frac=1)
drug_df.head(3)
# Out:
#     Age Sex      BP Cholesterol  Na_to_K   Drug
# 2    47   M     LOW        HIGH   10.114  drugC
# 59   34   M    HIGH        HIGH   18.703  DrugY
# 89   50   F  NORMAL      NORMAL   17.211  DrugY

# %%
from sklearn.model_selection import train_test_split

X = drug_df.drop("Drug", axis=1).values
y = drug_df.Drug.values

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=125
)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder, StandardScaler

cat_col = [1,2,3]
num_col = [0,4]

transform = ColumnTransformer(
    [
        ("encoder", OrdinalEncoder(), cat_col),
        ("num_imputer", SimpleImputer(strategy="median"), num_col),
        ("num_scaler", StandardScaler(), num_col),
    ]
)
pipe = Pipeline(
    steps=[
        ("preprocessing", transform),
        ("model", RandomForestClassifier(n_estimators=100, random_state=125)),
    ]
)
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('encoder', OrdinalEncoder(),
#                                                   [1, 2, 3]),
#                                                  ('num_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   [0, 4]),
#                                                  ('num_scaler',
#                                                   StandardScaler(), [0, 4])])),
#                 ('model', RandomForestClassifier(random_state=125))])

# %%
from sklearn.metrics import accuracy_score, f1_score

predictions = pipe.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
f1 = f1_score(y_test, predictions, average="macro")

print("Accuracy:", str(round(accuracy, 2) * 100) + "%", "F1:", round(f1, 2))
# Out:
# Accuracy: 95.0% F1: 0.91

# %%
with open("Results/metrics.txt", "w") as outfile:
    outfile.write(f"\nAccuracy = {accuracy}, F1 Score = {f1:.2f}.")

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

cm = confusion_matrix(y_test, predictions, labels=pipe.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipe.classes_)
disp.plot()
plt.savefig("Results/model_results.png", dpi=120)

# %%
! pip install skops
# Out:
# Collecting skops
#   Downloading skops-0.13.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: numpy>=1.25.0 in d:\ai study\cicd\cicd for ml\learn1\.venv\lib\site-packages (from skops) (2.3.5)
# Requirement already satisfied: packaging>=17.0 in d:\ai study\cicd\cicd for ml\learn1\.venv\lib\site-packages (from skops) (25.0)
# Collecting prettytable>=3.9 (from skops)
#   Downloading prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: scikit-learn>=1.2 in d:\ai study\cicd\cicd for ml\learn1\.venv\lib\site-packages (from skops) (1.7.2)
# Requirement already satisfied: scipy>=1.10.0 in d:\ai study\cicd\cicd for ml\learn1\.venv\lib\site-packages (from skops) (1.16.3)
# Requirement already satisfied: wcwidth in d:\ai study\cicd\cicd for ml\learn1\.venv\lib\site-packages (from prettytable>=3.9->skops) (0.2.14)
# Requirement already satisfied: joblib>=1.2.0 in d:\ai study\cicd\cicd for ml\learn1\.venv\lib\site-packages (from scikit-learn>=1.2->skops) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\ai study\cicd\cicd for ml\learn1\.venv\lib\site-packages (from scikit-learn>=1.2->skops) (3.6.0)
# Downloading skops-0.13.0-py3-none-any.whl (131 kB)
# Downloading prettytable-3.17.0-py3-none-any.whl (34 kB)
# Installing collected packages: prettytable, skops
#
#    -------------------- ------------------- 1/2 [skops]
#    -------------------- ------------------- 1/2 [skops]
#    ---------------------------------------- 2/2 [skops]
#
# Successfully installed prettytable-3.17.0 skops-0.13.0
# Could not find platform independent libraries <prefix>

# %%
import skops.io as sio

sio.dump(pipe, "Model/drug_pipeline.skops")
